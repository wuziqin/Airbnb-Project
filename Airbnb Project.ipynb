# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000 >LA Area AirBNB Negative Reviews Analysis (Zoe Wu)

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 1: Import the package and download the dataset

# %% [markdown]
# <font face="微软雅黑" size=2 color=#000000 >I downloaded the listings and reviews dataset from insideairbnb.com for analysis.

# %% [markdown]
# <font face="微软雅黑" size=2 color=#000000 >This notebook contains part of my analysis, for a well-rounded view of the analysis process, please refer to the EXCEL for more information.

# %%
import pandas as pd
import numpy as np
#Detailed review dataset
df_rev_d = pd.read_csv("reviews_d.csv")
#Detailed listings dataset
df_lst_d = pd.read_csv("listings_d.csv")
#summarized review dataset
df_rev_s = pd.read_csv("reviews_s.csv")
#summarized listing datase
df_lst_s = pd.read_csv("listings_s.csv")

# %%
df_rev_d
# Out:
#          listing_id         id        date  reviewer_id reviewer_name  \
# 0               109     449036  2011-08-15       927861         Edwin
# 1               109   74506539  2016-05-15     22509885          Jenn
# 2              2708   13994902  2014-06-09     10905424       Kuberan
# 3              2708   14606598  2014-06-23      2247288       Camilla
# 4              2708   39597339  2015-07-25     27974696        Fallon
# ...             ...        ...         ...          ...           ...
# 1069843    48014406  728886467  2021-02-04    181366823      Jennifer
# 1069844    48024697  729648516  2021-02-07     89652279        Joanna
# 1069845    48033228  729077755  2021-02-05     75024894          Gary
# 1069846    48033228  729670618  2021-02-07    367100663       Biannca
# 1069847    48055908  729700732  2021-02-07     56631207         Cansu
#
#                                                   comments
# 0        The host canceled my reservation the day befor...
# 1        Me and two friends stayed for four and a half ...
# 2        i had a wonderful stay. Everything from start ...
# 3        Charles is just amazing and he made my stay sp...
# 4        Staying with Chas was an absolute pleasure. He...
# ...                                                    ...
# 1069843  Stayed here for a night and it was just what w...
# 1069844                                            nice :)
# 1069845                                         great view
# 1069846  Got this place last minute and I wish I could ...
# 1069847  It was much better than what I was expected. T...
#
# [1069848 rows x 6 columns]

# %%
df_rev_s
# Out:
#          listing_id        date
# 0               109  2011-08-15
# 1               109  2016-05-15
# 2              2708  2014-06-09
# 3              2708  2014-06-23
# 4              2708  2015-07-25
# ...             ...         ...
# 1069843    48014406  2021-02-04
# 1069844    48024697  2021-02-07
# 1069845    48033228  2021-02-05
# 1069846    48033228  2021-02-07
# 1069847    48055908  2021-02-07
#
# [1069848 rows x 2 columns]

# %%
df_lst_d
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20210207181900
# 1          2708      https://www.airbnb.com/rooms/2708  20210207181900
# 2          2732      https://www.airbnb.com/rooms/2732  20210207181900
# 3          2864      https://www.airbnb.com/rooms/2864  20210207181900
# 4          5728      https://www.airbnb.com/rooms/5728  20210207181900
# ...         ...                                    ...             ...
# 31895  48070933  https://www.airbnb.com/rooms/48070933  20210207181900
# 31896  48070985  https://www.airbnb.com/rooms/48070985  20210207181900
# 31897  48071306  https://www.airbnb.com/rooms/48071306  20210207181900
# 31898  48071488  https://www.airbnb.com/rooms/48071488  20210207181900
# 31899  48072320  https://www.airbnb.com/rooms/48072320  20210207181900
#
#       last_scraped                                               name  \
# 0       2021-02-09  Amazing bright elegant condo park front *UPGRA...
# 1       2021-02-09  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...
# 2       2021-02-09                              Zen Life at the Beach
# 3       2021-02-09             * Beautiful Master Suite/Jacuzzi Tub/*
# 4       2021-02-10    Tiny Home in Artistic Oasis near Venice and LAX
# ...            ...                                                ...
# 31895   2021-02-09                 clean and comfortable room to rest
# 31896   2021-02-09                               quiet and clean room
# 31897   2021-02-09  LOWER PRICE and Deep Cleaning+Pool+Free Parkin...
# 31898   2021-02-10                           Historical Mansion Hotel
# 31899   2021-02-10                                    Happy home 快乐之家
#
#                                              description  \
# 0      *** Unit upgraded with new bamboo flooring, br...
# 1      Run Runyon Canyon<br /><br />Beautifully Furni...
# 2      An oasis of tranquility awaits you.<br /><br /...
# 3      Centrally located.... Furnished with King Size...
# 4      Our home is located near Venice Beach without ...
# ...                                                  ...
# 31895  A comfortable and clean room prepared for gues...
# 31896                   a quiet and clean place to rest.
# 31897  The apartment is located in a very safe and be...
# 31898  This Historical Mansion was owned by Judge Cha...
# 31899  房子离公园、超市、学校、购物广场都很近、生活非常之便利。房子里基本配备所有需要的设施、让你的...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1      Walk and run to Runyon Canyon, it is open!<br ...
# 2      This is the best part of Santa Monica. Quiet, ...
# 3      What makes the neighborhood unique is that the...
# 4      Our neighborhood is very quiet and save. There...
# ...                                                  ...
# 31895                                                NaN
# 31896                                                NaN
# 31897  All types of the restaurants are waiting for y...
# 31898                                                NaN
# 31899  离Ralps 开车5分钟、离购物商场开车7分钟左右、离附近的公园开车7分钟左右。上高速也很近...
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/4321499/1da98...        521
# 1      https://a0.muscache.com/pictures/miso/Hosting-...       3008
# 2      https://a0.muscache.com/pictures/1082974/0f74c...       3041
# 3      https://a0.muscache.com/pictures/23817858/de20...       3207
# 4      https://a0.muscache.com/pictures/7a29d275-f293...       9171
# ...                                                  ...        ...
# 31895  https://a0.muscache.com/pictures/cce8153b-0dc5...  387568794
# 31896  https://a0.muscache.com/pictures/10755099-2ede...  387568794
# 31897  https://a0.muscache.com/pictures/41e68445-0ae1...  106941010
# 31898  https://a0.muscache.com/pictures/3cbbd935-7b25...    8402388
# 31899  https://a0.muscache.com/pictures/5ee02bf5-d404...   45258263
#
#                                           host_url  ...  \
# 0            https://www.airbnb.com/users/show/521  ...
# 1           https://www.airbnb.com/users/show/3008  ...
# 2           https://www.airbnb.com/users/show/3041  ...
# 3           https://www.airbnb.com/users/show/3207  ...
# 4           https://www.airbnb.com/users/show/9171  ...
# ...                                            ...  ...
# 31895  https://www.airbnb.com/users/show/387568794  ...
# 31896  https://www.airbnb.com/users/show/387568794  ...
# 31897  https://www.airbnb.com/users/show/106941010  ...
# 31898    https://www.airbnb.com/users/show/8402388  ...
# 31899   https://www.airbnb.com/users/show/45258263  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             8.0                   10.0                 8.0
# 1                            10.0                   10.0                10.0
# 2                             9.0                   10.0                 9.0
# 3                             NaN                    NaN                 NaN
# 4                            10.0                   10.0                 9.0
# ...                           ...                    ...                 ...
# 31895                         NaN                    NaN                 NaN
# 31896                         NaN                    NaN                 NaN
# 31897                         NaN                    NaN                 NaN
# 31898                         NaN                    NaN                 NaN
# 31899                         NaN                    NaN                 NaN
#
#                                                  license instant_bookable  \
# 0                                                    NaN                f
# 1                                                    NaN                t
# 2                                                 228269                f
# 3                                                    NaN                t
# 4                                                    NaN                f
# ...                                                  ...              ...
# 31895                                                NaN                t
# 31896                                                NaN                f
# 31897  Exempt - This listing is a transient occupancy...                t
# 31898                                                NaN                f
# 31899                                                NaN                t
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  2
# 2                                  2
# 3                                  1
# 4                                  4
# ...                              ...
# 31895                              3
# 31896                              3
# 31897                             13
# 31898                              5
# 31899                              2
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               0
# 2                                               1
# 3                                               1
# 4                                               1
# ...                                           ...
# 31895                                           0
# 31896                                           0
# 31897                                          13
# 31898                                           5
# 31899                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                1
# 3                                                0
# 4                                                3
# ...                                            ...
# 31895                                            3
# 31896                                            3
# 31897                                            0
# 31898                                            0
# 31899                                            2
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.02
# 1                                               0              0.34
# 2                                               0              0.18
# 3                                               0               NaN
# 4                                               0              2.20
# ...                                           ...               ...
# 31895                                           0               NaN
# 31896                                           0               NaN
# 31897                                           0               NaN
# 31898                                           0               NaN
# 31899                                           0               NaN
#
# [31900 rows x 74 columns]

# %%
df_lst_s
# Out:
#              id                                               name    host_id  \
# 0           109  Amazing bright elegant condo park front *UPGRA...        521
# 1          2708  Runyon Canyon  | Beau Furn Mir Mini-Suite Fire...       3008
# 2          2732                              Zen Life at the Beach       3041
# 3          2864             * Beautiful Master Suite/Jacuzzi Tub/*       3207
# 4          5728    Tiny Home in Artistic Oasis near Venice and LAX       9171
# ...         ...                                                ...        ...
# 31895  48070933                 clean and comfortable room to rest  387568794
# 31896  48070985                               quiet and clean room  387568794
# 31897  48071306  LOWER PRICE and Deep Cleaning+Pool+Free Parkin...  106941010
# 31898  48071488                           Historical Mansion Hotel    8402388
# 31899  48072320                                    Happy home 快乐之家   45258263
#
#             host_name   neighbourhood_group    neighbourhood  latitude  \
# 0               Paolo          Other Cities      Culver City  33.98209
# 1               Chas.   City of Los Angeles        Hollywood  34.09768
# 2      Yoga Priestess          Other Cities     Santa Monica  34.00475
# 3           Bernadine          Other Cities       Bellflower  33.87619
# 4               Sanni   City of Los Angeles          Del Rey  33.98750
# ...               ...                   ...              ...       ...
# 31895          Sergio  Unincorporated Areas  Rowland Heights  33.98763
# 31896          Sergio  Unincorporated Areas  Rowland Heights  33.98740
# 31897           Linda   City of Los Angeles         Westwood  34.06114
# 31898         Jessica          Other Cities         Glendora  34.15155
# 31899            Zhou          Other Cities          Arcadia  34.10909
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -118.38494  Entire home/apt    115              30                  2
# 1     -118.34602     Private room     71              30                 28
# 2     -118.48127     Private room    155               1                 21
# 3     -118.11397  Entire home/apt     50              30                  0
# 4     -118.43200     Private room     42              30                310
# ...          ...              ...    ...             ...                ...
# 31895 -117.88529     Private room     36               1                  0
# 31896 -117.88588     Private room     28               1                  0
# 31897 -118.44367  Entire home/apt    176               1                  0
# 31898 -117.87664  Entire home/apt    195               1                  0
# 31899 -118.05121     Private room     45               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2016-05-15               0.02                               1
# 1      2020-11-08               0.34                               2
# 2      2019-12-27               0.18                               2
# 3             NaN                NaN                               1
# 4      2020-04-29               2.20                               4
# ...           ...                ...                             ...
# 31895         NaN                NaN                               3
# 31896         NaN                NaN                               3
# 31897         NaN                NaN                              13
# 31898         NaN                NaN                               5
# 31899         NaN                NaN                               2
#
#        availability_365
# 0                     0
# 1                   315
# 2                   365
# 3                     0
# 4                     1
# ...                 ...
# 31895               180
# 31896               179
# 31897               270
# 31898               362
# 31899               343
#
# [31900 rows x 16 columns]

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 2: Using NLP to conduct sentiment analysis and add label to reviews

# %%
#build the vader analyzer
# !pip install vaderSentiment
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# Requirement already satisfied: vaderSentiment in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: requests in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from vaderSentiment) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.10)
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/wuzoey/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Using Vader Analyzer to analyze the negative reviews
df_rev_d['comments'] = df_rev_d['comments'].astype(str)
df_rev_d['compound'] = df_rev_d['comments'].apply(lambda x:analyzer.polarity_scores(x)['compound'])
df_rev_d
# Out:
#          listing_id         id        date  reviewer_id reviewer_name  \
# 0               109     449036  2011-08-15       927861         Edwin
# 1               109   74506539  2016-05-15     22509885          Jenn
# 2              2708   13994902  2014-06-09     10905424       Kuberan
# 3              2708   14606598  2014-06-23      2247288       Camilla
# 4              2708   39597339  2015-07-25     27974696        Fallon
# ...             ...        ...         ...          ...           ...
# 1069843    48014406  728886467  2021-02-04    181366823      Jennifer
# 1069844    48024697  729648516  2021-02-07     89652279        Joanna
# 1069845    48033228  729077755  2021-02-05     75024894          Gary
# 1069846    48033228  729670618  2021-02-07    367100663       Biannca
# 1069847    48055908  729700732  2021-02-07     56631207         Cansu
#
#                                                   comments  compound
# 0        The host canceled my reservation the day befor...    0.0000
# 1        Me and two friends stayed for four and a half ...    0.9316
# 2        i had a wonderful stay. Everything from start ...    0.8126
# 3        Charles is just amazing and he made my stay sp...    0.9909
# 4        Staying with Chas was an absolute pleasure. He...    0.9672
# ...                                                    ...       ...
# 1069843  Stayed here for a night and it was just what w...    0.7755
# 1069844                                            nice :)    0.7003
# 1069845                                         great view    0.6249
# 1069846  Got this place last minute and I wish I could ...    0.9574
# 1069847  It was much better than what I was expected. T...    0.9408
#
# [1069848 rows x 7 columns]

# %%
#add label to the reviews
def compute_sati(x):
    if x>= 0.05:
        return 1
    elif x<= -0.05:
        return -1
    else:
        return 0
    

df_rev_d["cus_sati"] =df_rev_d["compound"].apply(compute_sati)

# %%
df_rev_d
# Out:
#          listing_id         id        date  reviewer_id reviewer_name  \
# 0               109     449036  2011-08-15       927861         Edwin
# 1               109   74506539  2016-05-15     22509885          Jenn
# 2              2708   13994902  2014-06-09     10905424       Kuberan
# 3              2708   14606598  2014-06-23      2247288       Camilla
# 4              2708   39597339  2015-07-25     27974696        Fallon
# ...             ...        ...         ...          ...           ...
# 1069843    48014406  728886467  2021-02-04    181366823      Jennifer
# 1069844    48024697  729648516  2021-02-07     89652279        Joanna
# 1069845    48033228  729077755  2021-02-05     75024894          Gary
# 1069846    48033228  729670618  2021-02-07    367100663       Biannca
# 1069847    48055908  729700732  2021-02-07     56631207         Cansu
#
#                                                   comments  compound  cus_sati
# 0        The host canceled my reservation the day befor...    0.0000         0
# 1        Me and two friends stayed for four and a half ...    0.9316         1
# 2        i had a wonderful stay. Everything from start ...    0.8126         1
# 3        Charles is just amazing and he made my stay sp...    0.9909         1
# 4        Staying with Chas was an absolute pleasure. He...    0.9672         1
# ...                                                    ...       ...       ...
# 1069843  Stayed here for a night and it was just what w...    0.7755         1
# 1069844                                            nice :)    0.7003         1
# 1069845                                         great view    0.6249         1
# 1069846  Got this place last minute and I wish I could ...    0.9574         1
# 1069847  It was much better than what I was expected. T...    0.9408         1
#
# [1069848 rows x 8 columns]

# %%
! pip install -U pandasql
# Out:
# Requirement already up-to-date: pandasql in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (0.7.3)
# Requirement already satisfied, skipping upgrade: sqlalchemy in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from pandasql) (1.3.20)
# Requirement already satisfied, skipping upgrade: pandas in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from pandasql) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from pandasql) (1.19.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
#import pandasql 
import pandasql as psql
from pandasql import sqldf

# %%
#find out the negative reviews from the positive reviews
q = "SELECT * FROM df_rev_d WHERE cus_sati <> 1"
df_unsati =psql.sqldf(q)

# %%
df_unsati
# Out:
#        listing_id         id        date  reviewer_id reviewer_name  \
# 0             109     449036  2011-08-15       927861         Edwin
# 1            2708  222420570  2017-12-29    155985882        Manami
# 2            5728   59744837  2016-01-14       303816         Tracy
# 3            5728   60341161  2016-01-22     16517963     Katharina
# 4            5728  142103781  2017-04-06     99657632       Mariela
# ...           ...        ...         ...          ...           ...
# 76699    47885081  729953921  2021-02-08    245246154        Briaja
# 76700    47887094  727523477  2021-01-29    345580260      Aierfate
# 76701    47887618  728896995  2021-02-04     24916090        Benson
# 76702    47893655  727338825  2021-01-28    378853640         Brian
# 76703    47924907  728252615  2021-01-31    366488486          Eric
#
#                                                 comments  compound  cus_sati
# 0      The host canceled my reservation the day befor...    0.0000         0
# 1      ﾎｽﾄはとても親切で英語の発音の仕方など丁寧に教えてくれた｡\n\n部屋はﾘﾋﾞﾝｸﾞを板で...    0.0000         0
# 2      The host canceled this reservation 88 days bef...    0.0000         0
# 3      Ich war zwar nur eine Nacht bei Sanni und Ihre...   -0.8748        -1
# 4      Súper acogedor y diferente, el cuarto es peque...    0.0000         0
# ...                                                  ...       ...       ...
# 76699                                Scammer Do Not Book    0.0000         0
# 76700        I will book this house again if I go to LA.    0.0000         0
# 76701  Sas place was everything my wife and I needed ...    0.0000         0
# 76702                           Can't wait to book again    0.0000         0
# 76703             Terrible place!! This place is a scam.   -0.8118        -1
#
# [76704 rows x 8 columns]

# %%
#output dataframe for further analysis in EXCEL
df_unsati.to_csv('review_analysis.csv')

# %%
# filter out the non_english reviews
df_rev_ana=df_unsati[df_unsati.comments.map(lambda x: x.isascii())]

# %%
#output dataframe for further analysis in EXCEL
df_rev_ana.to_csv('review_analysis_alleng.csv')

# %%
#reset the index
df_rev_ana=df_rev_ana.reset_index(drop=True)
df_rev_ana
# Out:
#        Unnamed: 0  listing_id         id        date  reviewer_id  \
# 0               0         109     449036  2011-08-15       927861
# 1               2        5728   59744837  2016-01-14       303816
# 2               7        5728  250947570  2018-04-06      3257952
# 3               8        5728  274631874  2018-06-09     17795184
# 4              10        5728  304071625  2018-08-08    205421234
# ...           ...         ...        ...         ...          ...
# 35214       76699    47885081  729953921  2021-02-08    245246154
# 35215       76700    47887094  727523477  2021-01-29    345580260
# 35216       76701    47887618  728896995  2021-02-04     24916090
# 35217       76702    47893655  727338825  2021-01-28    378853640
# 35218       76703    47924907  728252615  2021-01-31    366488486
#
#       reviewer_name                                           comments  \
# 0             Edwin  The host canceled my reservation the day befor...
# 1             Tracy  The host canceled this reservation 88 days bef...
# 2             Cloey                                       As described
# 3            Grisel  Perfecta estadia! Nos encanto la Tiny House. T...
# 4           Bastien  Wonderfull place to stay in LA near Venice Bea...
# ...             ...                                                ...
# 35214        Briaja                                Scammer Do Not Book
# 35215      Aierfate        I will book this house again if I go to LA.
# 35216        Benson  Sas place was everything my wife and I needed ...
# 35217         Brian                           Can't wait to book again
# 35218          Eric             Terrible place!! This place is a scam.
#
#        compound  cus_sati
# 0        0.0000         0
# 1        0.0000         0
# 2        0.0000         0
# 3       -0.4724        -1
# 4        0.0000         0
# ...         ...       ...
# 35214    0.0000         0
# 35215    0.0000         0
# 35216    0.0000         0
# 35217    0.0000         0
# 35218   -0.8118        -1
#
# [35219 rows x 9 columns]

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 3: Calculate the negative reviews rate

# %%
#calculate the total number of reviews
li_year=df_rev_ana["date"].apply(lambda x:x[:4]).tolist()
dic_year= {'2021': 0,'2020': 0,'2019': 0,'2018': 0,'2017': 0,'2016': 0,'2015': 0,'2014': 0,'2013': 0,'2012': 0,'2011': 0,'2010': 0}
key_list =dic_year.keys()
for i in li_year:
    for x in key_list:
        if i==x:
            dic_year[x]+=1
dic_year
# Out:
# {'2021': 697,
#  '2020': 7923,
#  '2019': 10688,
#  '2018': 6999,
#  '2017': 4629,
#  '2016': 2539,
#  '2015': 1031,
#  '2014': 460,
#  '2013': 166,
#  '2012': 63,
#  '2011': 23,
#  '2010': 1}

# %%
li_year_tot=df_rev_d["date"].apply(lambda x:x[:4]).tolist()
dic_year_tot= {'2021': 0,'2020': 0,'2019': 0,'2018': 0,'2017': 0,'2016': 0,'2015': 0,'2014': 0,'2013': 0,'2012': 0,'2011': 0,'2010': 0}
key_list_tot =dic_year_tot.keys()
for i in li_year_tot:
    for x in key_list_tot:
        if i==x:
            dic_year_tot[x]+=1
dic_year_tot
# Out:
# {'2021': 16995,
#  '2020': 208217,
#  '2019': 315249,
#  '2018': 221354,
#  '2017': 142083,
#  '2016': 89211,
#  '2015': 44467,
#  '2014': 19446,
#  '2013': 7860,
#  '2012': 3321,
#  '2011': 1355,
#  '2010': 270}

# %%
#calculate the negative reviews rate
dic_negV_perc= {'2021': 0,'2020': 0,'2019': 0,'2018': 0,'2017': 0,'2016': 0,'2015': 0,'2014': 0,'2013': 0,'2012': 0,'2011': 0,'2010': 0}
key_list_perc=dic_negV_perc.keys()
for i in key_list_perc:
    dic_negV_perc[i]=dic_year[i]/dic_year_tot[i]
dic_negV_perc
# Out:
# {'2021': 0.04101206237128567,
#  '2020': 0.03805164804026569,
#  '2019': 0.0339033589321457,
#  '2018': 0.031619035571979724,
#  '2017': 0.032579548573720994,
#  '2016': 0.028460615843337703,
#  '2015': 0.023185733240380507,
#  '2014': 0.023655250437107887,
#  '2013': 0.021119592875318068,
#  '2012': 0.018970189701897018,
#  '2011': 0.016974169741697416,
#  '2010': 0.003703703703703704}

# %%
#change the dictionary to a dataframe 
df_negV_perc = pd.DataFrame(dic_negV_perc,index=[0]) 
df_negV_perc
# Out:
#        2021      2020      2019      2018     2017      2016      2015  \
# 0  0.041012  0.038052  0.033903  0.031619  0.03258  0.028461  0.023186
#
#        2014     2013     2012      2011      2010
# 0  0.023655  0.02112  0.01897  0.016974  0.003704

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 4: Using NLTK to find the most common words in negative reviews.

# %%
# Get the date in int type
df_rev_ana["date_num"] = df_rev_ana["date"].apply(lambda str_x: int("".join(str_x.split("-"))))
df_rev_ana.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0         109     449036  2011-08-15       927861         Edwin
# 1        5728   59744837  2016-01-14       303816         Tracy
# 2        5728  250947570  2018-04-06      3257952         Cloey
# 3        5728  274631874  2018-06-09     17795184        Grisel
# 4        5728  304071625  2018-08-08    205421234       Bastien
#
#                                             comments  compound  cus_sati  \
# 0  The host canceled my reservation the day befor...    0.0000         0
# 1  The host canceled this reservation 88 days bef...    0.0000         0
# 2                                       As described    0.0000         0
# 3  Perfecta estadia! Nos encanto la Tiny House. T...   -0.4724        -1
# 4  Wonderfull place to stay in LA near Venice Bea...    0.0000         0
#
#    date_num
# 0  20110815
# 1  20160114
# 2  20180406
# 3  20180609
# 4  20180808

# %%
import nltk
import string
import copy
from nltk.corpus import stopwords

nltk.download('stopwords')
set_stopwords = set(stopwords.words('english'))
set_illegalwords = set_stopwords.union(set(range(10)))
# Punctuation set 
str_punc = string.punctuation + "\n\r"

dic_word_freq_ana = {}


def word_freq(sentence):
    if type(sentence) != str:
        sentence = str(sentence)
    sentence = sentence.lower()
    ls_stc = sentence.strip(str_punc).split(" ")
    for word in ls_stc:
        clean_word = word.strip(str_punc)
        if (clean_word not in set_illegalwords) and clean_word != '':
            if clean_word not in dic_word_freq.keys():
                dic_word_freq[clean_word] = 1
            else:
                dic_word_freq[clean_word] += 1

                
dic_word_freq= {}
df_rev_ana["comments"].apply(word_freq)
dic_word_freq_ana = copy.deepcopy(dic_word_freq)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/wuzoey/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create dataframes of frequencies. 
df_word_freq_ana   = pd.DataFrame.from_dict(dic_word_freq_ana, orient = 'index', columns = ["Frequency"])
df_word_freq_ana  .sort_values(by = "Frequency", ascending = False, inplace = True)
df_word_freq_ana
# Out:
#                      Frequency
# host                      9248
# place                     7594
# arrival                   6208
# reservation               6067
# canceled                  5856
# ...                        ...
# that.\r\n\r\nin              1
# out.\r\n\r\nday              1
# evening.\r\n\r\nday          1
# traps.\r\n\r\nday            1
# sas                          1
#
# [33175 rows x 1 columns]

# %%
df_word_freq_ana.to_csv("word_freq_ana.csv")

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 5: Building dataset for further analysis on the listings with high negative reviews rate

# %%
df_mer=pd.merge(df_lst_s,df_rev_ana,left_on="id",right_on="listing_id")

# %%
df_mer.to_csv('review_analysis_mer.csv')

# %%
df_num_nrev_ana=pd.read_csv("num_nrev.csv")

# %%
df_mer_nrev=pd.merge(df_lst_s,df_num_nrev_ana,left_on="id",right_on="Listing_id")

# %%
df_mer_nrev.rename(columns = {"number of negative reviews": "num_neg_rev"},  inplace=True)
df_mer_nrev
# Out:
#              id                                               name    host_id  \
# 0           109  Amazing bright elegant condo park front *UPGRA...        521
# 1          5728    Tiny Home in Artistic Oasis near Venice and LAX       9171
# 2          5729     Zen Room with Floating Bed near Venice and LAX       9171
# 3          5843  Artist Oasis near Venice Beach w/ Beautiful Ga...       9171
# 4          6931  Run Runyon | Beau Furn Rm  Dres Rm/Wlk-In Clst...       3008
# ...         ...                                                ...        ...
# 12308  47885081  Modern 2 BR Apartment in the Best Area of Down...  376006182
# 12309  47887094  Luxury Modern Home East Hollywood w/ Rooftop Deck  256687192
# 12310  47887618     LUXURY ENTERTAINERS DELIGHT IN THE HEART OF LA    6986531
# 12311  47893655  Fantastic 3bd + Beverly Hills + OPEN SKY DECK ...  120293132
# 12312  47924907  Private room, nice decor house cheap rooMTorrance  344244278
#
#             host_name  neighbourhood_group    neighbourhood  latitude  \
# 0               Paolo         Other Cities      Culver City  33.98209
# 1               Sanni  City of Los Angeles          Del Rey  33.98750
# 2               Sanni  City of Los Angeles          Del Rey  33.98750
# 3               Sanni  City of Los Angeles          Del Rey  33.98750
# 4               Chas.  City of Los Angeles        Hollywood  34.09521
# ...               ...                  ...              ...       ...
# 12308         Sharait  City of Los Angeles  Atwater Village  34.11421
# 12309  Edgar And Zola  City of Los Angeles      Silver Lake  34.09431
# 12310             Sas  City of Los Angeles    Beverly Grove  34.08622
# 12311          Jordan  City of Los Angeles    Beverly Grove  34.07292
# 12312             Tye         Other Cities         Torrance  33.87564
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -118.38494  Entire home/apt    115              30                  2
# 1     -118.43200     Private room     42              30                310
# 2     -118.43200     Private room     65              30                230
# 3     -118.43200  Entire home/apt    130              30                128
# 4     -118.34801     Private room     71              30                 24
# ...          ...              ...    ...             ...                ...
# 12308 -118.26498  Entire home/apt    199               2                  1
# 12309 -118.28068  Entire home/apt    441               2                  2
# 12310 -118.36661  Entire home/apt    890               1                  1
# 12311 -118.38417  Entire home/apt    329               1                  1
# 12312 -118.34812     Private room     85               1                  1
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2016-05-15               0.02                               1
# 1      2020-04-29               2.20                               4
# 2      2020-04-11               1.65                               4
# 3      2020-08-22               1.08                               4
# 4      2021-01-15               0.17                               2
# ...           ...                ...                             ...
# 12308  2021-02-08               1.00                               2
# 12309  2021-01-31               2.00                               9
# 12310  2021-02-04               1.00                               1
# 12311  2021-01-28               1.00                               4
# 12312  2021-01-31               1.00                               1
#
#        availability_365  Listing_id  num_neg_rev
# 0                     0         109            1
# 1                     1        5728            6
# 2                   283        5729           10
# 3                    15        5843            4
# 4                   260        6931            2
# ...                 ...         ...          ...
# 12308               360    47885081            1
# 12309               354    47887094            1
# 12310               322    47887618            1
# 12311               361    47893655            1
# 12312               365    47924907            1
#
# [12313 rows x 18 columns]

# %%
df_mer_nrev.to_csv('nrev_analysis.csv')

# %%
df_mer_nrev.sort_values(by=["num_neg_rev"], ascending=False)
# Out:
#              id                                               name    host_id  \
# 344      756777                                Private Room by LAX    3659692
# 1806    6044166               Central Los Angeles/ Private Studio.   30906832
# 401      879195                 Private room with private entrance    3659692
# 5574   20057869  SweetHome-Close to Beach, LA Airport &Freeway 405   25174468
# 72       107970                  2 Room Poolside Guesthouse +bikes     552845
# ...         ...                                                ...        ...
# 6326   21999433  T307 - Large top floor 2bed/2bath in Century City  159480876
# 6325   21998061  Stunning Modern Apartment - Top Comfort, Perfe...   74329020
# 6323   21993833             Charming 1920s West Hollywood Bungalow   34457781
# 6321   21992923       3rd bd, 1 ba in my peaceful, southwest home.   81704121
# 12312  47924907  Private room, nice decor house cheap rooMTorrance  344244278
#
#            host_name   neighbourhood_group     neighbourhood  latitude  \
# 344    Chanoma House          Other Cities        El Segundo  33.91920
# 1806           Harry   City of Los Angeles   Harvard Heights  34.03776
# 401    Chanoma House          Other Cities        El Segundo  33.92013
# 5574           Betty  Unincorporated Areas          Del Aire  33.90303
# 72             Ronan          Other Cities        Long Beach  33.77435
# ...              ...                   ...               ...       ...
# 6326        Urbanlux   City of Los Angeles  West Los Angeles  34.05495
# 6325         Michael   City of Los Angeles    Pico-Robertson  34.05093
# 6323         Michael          Other Cities    West Hollywood  34.09131
# 6321       Elizabeth  Unincorporated Areas       Sun Village  34.53144
# 12312            Tye          Other Cities          Torrance  33.87564
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 344   -118.39797     Private room     49               1                511
# 1806  -118.30285  Entire home/apt     70               1                411
# 401   -118.39643     Private room     48               1                426
# 5574  -118.36797  Entire home/apt    149               1                288
# 72    -118.12275  Entire home/apt     40               3                764
# ...          ...              ...    ...             ...                ...
# 6326  -118.42590  Entire home/apt    210              31                  7
# 6325  -118.38132  Entire home/apt    110              30                105
# 6323  -118.35549  Entire home/apt    109              31                  7
# 6321  -117.96936     Private room    100               1                 23
# 12312 -118.34812     Private room     85               1                  1
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 344    2021-01-24               5.12                               6
# 1806   2021-01-23               5.84                               4
# 401    2021-01-19               4.35                               6
# 5574   2021-02-04               6.69                               2
# 72     2021-01-16               6.54                               1
# ...           ...                ...                             ...
# 6326   2021-01-05               0.19                              49
# 6325   2021-01-16               2.76                               2
# 6323   2020-05-15               0.19                               1
# 6321   2020-08-31               0.63                               4
# 12312  2021-01-31               1.00                               1
#
#        availability_365  Listing_id  num_neg_rev
# 344                 360      756777           55
# 1806                 73     6044166           46
# 401                   0      879195           46
# 5574                178    20057869           37
# 72                  259      107970           36
# ...                 ...         ...          ...
# 6326                269    21999433            1
# 6325                131    21998061            1
# 6323                345    21993833            1
# 6321                342    21992923            1
# 12312               365    47924907            1
#
# [12313 rows x 18 columns]

# %% [markdown]
# <font face="微软雅黑" size=5 color=#000000 >STEP 6: Interactive map visualizing the distribution of the negative reviews in LA

# %%
! pip install folium
# Define the world map
import folium
world_map = folium.Map()

# Los Angeles latitude and longitude values
latitude = 34.03
longitude =  -118.15

# Create the map and display the map of LA
LA_map = folium.Map(location=[latitude, longitude], zoom_start=10)
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 243 kB/s eta 0:00:011
# Requirement already satisfied: numpy in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.19.2)
# Requirement already satisfied: requests in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/wuzoey/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %%
LA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_260b1d57f5e74ff9a1d216c1c0a241da%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_260b1d57f5e74ff9a1d216c1c0a241da%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_260b1d57f5e74ff9a1d216c1c0a241da%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_260b1d57f5e74ff9a1d216c1c0a241da%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.03%2C%20-118.15%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Get the first 1000 listings
limit = 1000
listing_limit = df_mer_nrev.iloc[0:limit,:]

# Initiate a feature group for the listings in the dataframe
listing_location = folium.map.FeatureGroup()

# Loop through the locations of the first 100 listings and add each to the listing_location feature group
for lat, lng, in zip(listing_limit.latitude, listing_limit.longitude):
    listing_location.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius = 4,
            color = "yellow",
            fill = True,
            fill_color = "red",
            fill_opacity = 0.4
        )
    )

# Add listing_location to the LA_map
LA_map = folium.Map(location=[latitude, longitude], zoom_start=10)
LA_map.add_child(listing_location)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c11a9c37bc4d4ef39f2ce6631b899f67%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c11a9c37bc4d4ef39f2ce6631b899f67%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c11a9c37bc4d4ef39f2ce6631b899f67%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c11a9c37bc4d4ef39f2ce6631b899f67%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.03%2C%20-118.15%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
from folium import plugins
LA_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# Initiate a mark cluster object for the listings
listing_cluster = plugins.MarkerCluster().add_to(LA_map)

# Loop through the dataframe and add each data point to the mark cluster
for lat,lng,nei, in zip(listing_limit.latitude, listing_limit.longitude, listing_limit.neighbourhood):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=nei,
    ).add_to(listing_cluster)

# Add listing_cluster to the LA_map
LA_map.add_child(listing_cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0703aea794fe442fb8e6de46cff6c28a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0703aea794fe442fb8e6de46cff6c28a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
